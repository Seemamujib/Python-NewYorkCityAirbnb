# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

#Turn project folder path to a string
path=r'C:\Users\19452\Desktop\Seema\Careerfoundry-Data Analytics Course\Work Area\Data Immersion\Achievement 6\PythonProject-NewYorkCityAirbnb\02 Data'

# %%
#Import Dataframe NewYorkCityAirbnb.csv
df=pd.read_csv(os.path.join(path,'Original Data','NewYorkCityAirbnb.csv'),index_col=False)

# Look at first few records of the dataframe
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Displays total number of rows and columns in products dataframe
df.shape
# Out:
# (48895, 16)

# %%
#Shows datatypes of each column in products dataframe
df.info()

#df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# Convert datatype of host_id column from integer to string
df['host_id']=df['host_id'].astype('str')

# Convert datatype of id column from integer to string
df['id']=str(df['id'])

# %%
# Rename column name    

df.rename(columns={'description':'name'},inplace=True)

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                            object
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# Check for missing values

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Look for Null values

dfnull=df[df['last_review'].isnull()==True]

dfnull
# Out:
#                                                       id  \
# 2      0            2539\n1            2595\n2       ...
# 19     0            2539\n1            2595\n2       ...
# 26     0            2539\n1            2595\n2       ...
# 36     0            2539\n1            2595\n2       ...
# 38     0            2539\n1            2595\n2       ...
# ...                                                  ...
# 48890  0            2539\n1            2595\n2       ...
# 48891  0            2539\n1            2595\n2       ...
# 48892  0            2539\n1            2595\n2       ...
# 48893  0            2539\n1            2595\n2       ...
# 48894  0            2539\n1            2595\n2       ...
#
#                                                     name   host_id  \
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19                     Huge 2 BR Upper East  Cental Park     17985
# 26     Magnifique Suite au N de Manhattan - vue Cloitres     26394
# ...

# %%
# Look for Null values

dfnull=df[df['reviews_per_month'].isnull()==True]
dfnull
# Out:
#                                                       id  \
# 2      0            2539\n1            2595\n2       ...
# 19     0            2539\n1            2595\n2       ...
# 26     0            2539\n1            2595\n2       ...
# 36     0            2539\n1            2595\n2       ...
# 38     0            2539\n1            2595\n2       ...
# ...                                                  ...
# 48890  0            2539\n1            2595\n2       ...
# 48891  0            2539\n1            2595\n2       ...
# 48892  0            2539\n1            2595\n2       ...
# 48893  0            2539\n1            2595\n2       ...
# 48894  0            2539\n1            2595\n2       ...
#
#                                                     name   host_id  \
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19                     Huge 2 BR Upper East  Cental Park     17985
# 26     Magnifique Suite au N de Manhattan - vue Cloitres     26394
# ...

# %%
# 'host_id' is a unique id that is present in the dataset. So the column 'id' is being removed
# Data from 'host_name',last_review' and 'reviews_per_month' columns will not be used in analysis 
# as they will not be required for answering any key questions. Thus, these columns are dropped.

df=df.drop(columns=['id','name','host_name','last_review','reviews_per_month'])

# %%
# Check for missing values

df.isnull().sum()
# Out:
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.head()
# Out:
#   host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0    2787            Brooklyn    Kensington  40.64749  -73.97237
# 1    2845           Manhattan       Midtown  40.75362  -73.98377
# 2    4632           Manhattan        Harlem  40.80902  -73.94190
# 3    4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4    7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# ...

# %%
# Find duplicates

df_dups = df[df.duplicated()]

# %%
df_dups.shape # No duplicates!
# Out:
# (0, 11)

# %%
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# name, host_name, last_review columns have mixed data which is expected.  They have special characters as part of data. 
# For ex, ther are names such as'Clement & Rose'
# Out:
# C:\Users\19452\AppData\Local\Temp\ipykernel_13208\820040488.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\19452\AppData\Local\Temp\ipykernel_13208\820040488.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\19452\AppData\Local\Temp\ipykernel_13208\820040488.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\19452\AppData\Local\Temp\ipykernel_13208\820040488.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %% [markdown]
# ### There are 48895 airbnb facilities in New York state
# ### Average price for airbnb is 153 dollars
# ### On an average customers stay for 7 days

# %%
#calculate descriptive statistics for each numeric column and suppress scientific notation

df.describe().apply(lambda x: x.apply('{0:.5f}'.format))
# Out:
#           latitude    longitude        price minimum_nights number_of_reviews  \
# count  48895.00000  48895.00000  48895.00000    48895.00000       48895.00000
# mean      40.72895    -73.95217    152.72069        7.02996          23.27447
# std        0.05453      0.04616    240.15417       20.51055          44.55058
# min       40.49979    -74.24442      0.00000        1.00000           0.00000
# 25%       40.69010    -73.98307     69.00000        1.00000           1.00000
# 50%       40.72307    -73.95568    106.00000        3.00000           5.00000
# 75%       40.76311    -73.93627    175.00000        5.00000          24.00000
# max       40.91306    -73.71299  10000.00000     1250.00000         629.00000
#
#       calculated_host_listings_count availability_365
# count                    48895.00000      48895.00000
# mean                         7.14398        112.78133
# std                         32.95252        131.62229
# ...

# %%
df.head()
# Out:
#   host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0    2787            Brooklyn    Kensington  40.64749  -73.97237
# 1    2845           Manhattan       Midtown  40.75362  -73.98377
# 2    4632           Manhattan        Harlem  40.80902  -73.94190
# 3    4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4    7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# ...

# %%
# list the observations with host_id '219517861' & '107434423'

df_hosts = df.loc[df['host_id'].isin(['219517861','107434423'])]
df_hosts
# Out:
#          host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 26137  107434423           Manhattan            Kips Bay  40.74510  -73.97915
# 29128  107434423           Manhattan  Financial District  40.70637  -74.00941
# 30158  107434423           Manhattan         Murray Hill  40.74900  -73.97961
# 30428  107434423           Manhattan         Murray Hill  40.74891  -73.97887
# 31506  107434423           Manhattan             Tribeca  40.71433  -74.01073
# ...          ...                 ...                 ...       ...        ...
# 48723  107434423           Manhattan              Nolita  40.72283  -73.99472
# 48724  107434423           Manhattan      Hell's Kitchen  40.76082  -73.99709
# 48725  107434423           Manhattan      Hell's Kitchen  40.76083  -73.99727
# 48726  107434423            Brooklyn        Williamsburg  40.71493  -73.96365
# 48727  107434423           Manhattan        East Village  40.73206  -73.98776
#
# ...

# %% [markdown]
# ## Visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### host_id 219517861 has 327 listings which is the highest among all

# %%
# count of host_id

df['host_id'].value_counts()
# Out:
# host_id
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: count, Length: 37457, dtype: int64

# %% [markdown]
# ### Manhattan and Brooklyn have the most listings
# ### Staten Island has the least

# %%
#count of neighbourhood_group

df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# create a neighbourhood group bar chart using matplotlib

#neighbourhood=df['neighbourhood_group'].value_counts().plot.bar(color=['#999','#799','#599','#399','#199'])
#plt.title('Listings in the neighbourhood group')
#plt.show()

# %%
# create a neighbourhood group bar chart using seaborn

sns.countplot(data=df, x='neighbourhood_group',palette="Set2")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood Group')
# Out:
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# ### Top 3 neighbourhoods that has most listings are: Williamsburg, Bedford-Stuyvesant and Harlem

# %%
# count of neighbourhood

df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %%
# create a neighbourhood bar chart using seaborn

sns.countplot(data=df, x='neighbourhood',palette="Set2")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood')
# Out:
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Neighbourhood')

# %% [markdown]
# ### Most of the properties are Entire home/apartment

# %%
#count of room_type

df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
# create a room_type bar chart using seaborn

sns.countplot(data=df, x='room_type',palette="Set2")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Room type availability')
# Out:
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Room type availability')

# %% [markdown]
# ### Majority of customers stay 1-3 nights

# %%
# Count of minimum_nights

df['minimum_nights'].value_counts()
# Out:
# minimum_nights
# 1      12720
# 2      11696
# 3       7999
# 30      3760
# 4       3303
#        ...
# 186        1
# 366        1
# 68         1
# 87         1
# 36         1
# Name: count, Length: 109, dtype: int64

# %%
# Count of minimum_nights>365.  
# There are 14 listings where minimum_nights are greater than 365.  
# This could be the specification the host may have while letting out their property, say, the guest should 
# stay minimum 1000 nights etc.

dft=df[df['minimum_nights']>365]

dft['minimum_nights'].value_counts()
# Out:
# minimum_nights
# 500     5
# 999     3
# 370     1
# 1000    1
# 1250    1
# 480     1
# 366     1
# 400     1
# Name: count, dtype: int64

# %%
# create a neighbourhood group bar chart using seaborn

sns.countplot(data=df, x='minimum_nights',palette="Set2")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Minimum Nights of stay')
# Out:
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\19452\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Minimum Nights of stay')

# %% [markdown]
# ### Host_ids with highest listings - 1,2,3,4,5

# %%
# count of calculated_host_listings_count

df['calculated_host_listings_count'].value_counts()
# Out:
# calculated_host_listings_count
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: count, dtype: int64

# %% [markdown]
# ### There are 1295 properties available for 365 days, 491 for 364 days and 408 for 1 day

# %%
# count of availability_365

df['availability_365'].value_counts()
# Out:
# availability_365
# 0      17533
# 365     1295
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: count, Length: 366, dtype: int64

# %%
df.dtypes
# Out:
# host_id                            object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
# export df to Prepared Dataset folder as a new file products_checked.csv

df.to_csv(os.path.join(path,'Prepared Data','6.1','NewYorkCityAirbnb_Clean.csv'),index=False)
